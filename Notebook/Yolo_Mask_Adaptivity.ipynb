# %% [markdown]
# ## Mask Adaptivity Detection Using YOLO
# ![cover](https://i.ibb.co/RBG6m20/cover.png)

# %%
import warnings
import numpy as np
import argparse
import time
import cv2
import os
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Prepare DarkNet Environment

# %%
# Create DarkNet Environment
def prepare_environment():
    os.environ['PATH'] += ':/usr/local/cuda/bin'
    # !rm -fr darknet
    # !git clone https://github.com/AlexeyAB/darknet/
    # !apt install gcc-5 g++-5 -y
    # !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
    # !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
    # %cd darknet
    # !sed -i 's/GPU=0/GPU=1/g' Makefile
    # !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
    # !make
    # get yolov3 weights
    #!wget https://pjreddie.com/media/files/darknet53.conv.74.weights
    # !chmod a+x ./darknet
    # !apt install ffmpeg libopencv-dev libgtk-3-dev python-numpy python3-numpy libdc1394-22 libdc1394-22-dev libjpeg-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip
    status='Completed'
    return status
prepare_environment()
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 13567 (delta 1), reused 1 (delta 0), pack-reused 13559
# Receiving objects: 100% (13567/13567), 12.20 MiB | 1.60 MiB/s, done.
# Resolving deltas: 100% (9256/9256), done.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0 libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 31 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libisl15 amd64 0.18-4 [548 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cpp-5 amd64 5.5.0-12ubuntu1 [7,785 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libasan2 amd64 5.5.0-12ubuntu1 [264 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmpx0 amd64 5.5.0-12ubuntu1 [9,888 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgcc-5-dev amd64 5.5.0-12ubuntu1 [2,224 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5 amd64 5.5.0-12ubuntu1 [8,357 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libstdc++-5-dev amd64 5.5.0-12ubuntu1 [1,415 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 g++-5 amd64 5.5.0-12ubuntu1 [8,450 kB]
# Fetched 29.1 MB in 6s (4,767 kB/s)
# Selecting previously unselected package gcc-5-base:amd64.
# (Reading database ... 144433 files and directories currently installed.)
# Preparing to unpack .../0-gcc-5-base_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libisl15:amd64.
# Preparing to unpack .../1-libisl15_0.18-4_amd64.deb ...
# Unpacking libisl15:amd64 (0.18-4) ...
# Selecting previously unselected package cpp-5.
# Preparing to unpack .../2-cpp-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking cpp-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libasan2:amd64.
# Preparing to unpack .../3-libasan2_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libasan2:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libmpx0:amd64.
# Preparing to unpack .../4-libmpx0_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libgcc-5-dev:amd64.
# Preparing to unpack .../5-libgcc-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package gcc-5.
# Preparing to unpack .../6-gcc-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libstdc++-5-dev:amd64.
# Preparing to unpack .../7-libstdc++-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package g++-5.
# Preparing to unpack .../8-g++-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking g++-5 (5.5.0-12ubuntu1) ...
# Setting up libisl15:amd64 (0.18-4) ...
# Setting up gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Setting up libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Setting up libasan2:amd64 (5.5.0-12ubuntu1) ...
# Setting up libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up cpp-5 (5.5.0-12ubuntu1) ...
# Setting up libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up gcc-5 (5.5.0-12ubuntu1) ...
# Setting up g++-5 (5.5.0-12ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^
# ./src/image_opencv.cpp:1367:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^
# ./src/image_opencv.cpp:1371:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^
# ./src/image_opencv.cpp:1375:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^
# ./src/image_opencv.cpp:1378:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#  ^
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#  ^
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:276:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                 ^
# ./src/dark_cuda.c:276:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
# ./src/dark_cuda.c:276:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
# ./src/dark_cuda.c:286:24: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                         ^
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:307:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                     ^
# ./src/dark_cuda.c:322:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                     ^
# ./src/dark_cuda.c:328:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                     ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1204:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:77:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/activations.c:77:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:287:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/activations.c:287:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1238:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1038:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:610:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1586:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:455:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:548:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:661:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^
# ./src/detector.c:659:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1280:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^
# ./src/detector.c:1279:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1796:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:196:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                                     ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:138:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:831:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1261:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^
# ./src/classifier.c:1261:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:16: warning: unused variable ‘prediction’ [-Wunused-variable]
#          float *prediction = network_predict(net, X);
#                 ^
# ./src/demo.c:98:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:58:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^
# ./src/region_layer.c:57:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:62:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:69:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:96:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:105:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1734): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1734): warning: variable "stage_id" was declared but never referenced
#
# ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../31-libgstreamer-plugins-base1.0-0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../32-libgstreamer-gl1.0-0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package gir1.2-gst-plugins-base-1.0:amd64.
# Preparing to unpack .../33-gir1.2-gst-plugins-base-1.0_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking gir1.2-gst-plugins-base-1.0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../34-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../35-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../36-gir1.2-gtk-3.0_3.22.30-1ubuntu4_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../37-libgraphene-1.0-0_1.8.0-1_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../38-gstreamer1.0-gl_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../39-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../40-libvisual-0.4-0_0.4.0-11_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-11) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../41-gstreamer1.0-plugins-base_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../42-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../43-libdbus-1-dev_1.12.2-1ubuntu1.1_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.1) ...
# Selecting previously unselected package x11proto-record-dev.
# Preparing to unpack .../44-x11proto-record-dev_2018.4-4_all.deb ...
# Unpacking x11proto-record-dev (2018.4-4) ...
# Selecting previously unselected package libxtst-dev:amd64.
# Preparing to unpack .../45-libxtst-dev_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst-dev:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libatspi2.0-dev:amd64.
# Preparing to unpack .../46-libatspi2.0-dev_2.28.0-1_amd64.deb ...
# Unpacking libatspi2.0-dev:amd64 (2.28.0-1) ...
# Selecting previously unselected package libatk-bridge2.0-dev:amd64.
# Preparing to unpack .../47-libatk-bridge2.0-dev_2.26.2-1_amd64.deb ...
# Unpacking libatk-bridge2.0-dev:amd64 (2.26.2-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../48-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../49-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../50-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../51-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../52-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libepoxy-dev:amd64.
# Preparing to unpack .../53-libepoxy-dev_1.4.3-1_amd64.deb ...
# Unpacking libepoxy-dev:amd64 (1.4.3-1) ...
# Selecting previously unselected package libfaac0:amd64.
# Preparing to unpack .../54-libfaac0_1.29.7.7-1_amd64.deb ...
# Unpacking libfaac0:amd64 (1.29.7.7-1) ...
# Selecting previously unselected package libfaac-dev:amd64.
# Preparing to unpack .../55-libfaac-dev_1.29.7.7-1_amd64.deb ...
# Unpacking libfaac-dev:amd64 (1.29.7.7-1) ...
# Selecting previously unselected package libffms2-4:amd64.
# Preparing to unpack .../56-libffms2-4_2.23-2_amd64.deb ...
# Unpacking libffms2-4:amd64 (2.23-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../57-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libgpac4:amd64.
# Preparing to unpack .../58-libgpac4_0.5.2-426-gc5ad4e4+dfsg5-3ubuntu0.1_amd64.deb ...
# Unpacking libgpac4:amd64 (0.5.2-426-gc5ad4e4+dfsg5-3ubuntu0.1) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../59-libgstreamer1.0-dev_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Adding 'diversion of /usr/bin/dh_gstscancodecs to /usr/bin/dh_gstscancodecs-gst0.10 by libgstreamer1.0-dev'
# Adding 'diversion of /usr/share/man/man1/dh_gstscancodecs.1.gz to /usr/share/man/man1/dh_gstscancodecs.1.gz-gst0.10 by libgstreamer1.0-dev'
# Unpacking libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package liborc-0.4-dev-bin.
# Preparing to unpack .../60-liborc-0.4-dev-bin_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-dev-bin (1:0.4.28-1) ...
# Selecting previously unselected package liborc-0.4-dev.
# Preparing to unpack .../61-liborc-0.4-dev_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-dev (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-dev:amd64.
# Preparing to unpack .../62-libgstreamer-plugins-base1.0-dev_1.14.5-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../63-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../64-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../65-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../66-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../67-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../68-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../69-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../70-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package wayland-protocols.
# Preparing to unpack .../71-wayland-protocols_1.13-1_all.deb ...
# Unpacking wayland-protocols (1.13-1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../72-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libgtk-3-dev:amd64.
# Preparing to unpack .../73-libgtk-3-dev_3.22.30-1ubuntu4_amd64.deb ...
# Unpacking libgtk-3-dev:amd64 (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../74-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../75-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libmp3lame-dev:amd64.
# Preparing to unpack .../76-libmp3lame-dev_3.100-2_amd64.deb ...
# Unpacking libmp3lame-dev:amd64 (3.100-2) ...
# Selecting previously unselected package libopencore-amrnb-dev:amd64.
# Preparing to unpack .../77-libopencore-amrnb-dev_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb-dev:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb-dev:amd64.
# Preparing to unpack .../78-libopencore-amrwb-dev_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb-dev:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libtheora-dev:amd64.
# Preparing to unpack .../79-libtheora-dev_1.1.1+dfsg.1-14_amd64.deb ...
# Unpacking libtheora-dev:amd64 (1.1.1+dfsg.1-14) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../80-libv4lconvert0_1.14.2-1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../81-libv4l-0_1.14.2-1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l2rds0:amd64.
# Preparing to unpack .../82-libv4l2rds0_1.14.2-1_amd64.deb ...
# Unpacking libv4l2rds0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l-dev:amd64.
# Preparing to unpack .../83-libv4l-dev_1.14.2-1_amd64.deb ...
# Unpacking libv4l-dev:amd64 (1.14.2-1) ...
# Selecting previously unselected package libxine2-bin.
# Preparing to unpack .../84-libxine2-bin_1.2.8-2build2_amd64.deb ...
# Unpacking libxine2-bin (1.2.8-2build2) ...
# Selecting previously unselected package libxine2-dev.
# Preparing to unpack .../85-libxine2-dev_1.2.8-2build2_amd64.deb ...
# Unpacking libxine2-dev (1.2.8-2build2) ...
# Selecting previously unselected package libxvidcore-dev:amd64.
# Preparing to unpack .../86-libxvidcore-dev_2%3a1.3.5-1_amd64.deb ...
# Unpacking libxvidcore-dev:amd64 (2:1.3.5-1) ...
# Selecting previously unselected package v4l-utils.
# Preparing to unpack .../87-v4l-utils_1.14.2-1_amd64.deb ...
# Unpacking v4l-utils (1.14.2-1) ...
# Selecting previously unselected package x264.
# Preparing to unpack .../88-x264_2%3a0.152.2854+gite9a5903-2_amd64.deb ...
# Unpacking x264 (2:0.152.2854+gite9a5903-2) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.1) ...
# Setting up libfaac0:amd64 (1.29.7.7-1) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libv4l2rds0:amd64 (1.14.2-1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libpam-cap:amd64 (1:2.25-1.2) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libtheora-dev:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libcap2-bin (1:2.25-1.2) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libv4lconvert0:amd64 (1.14.2-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up libffms2-4:amd64 (2.23-2) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up x11proto-record-dev (2018.4-4) ...
# Setting up libxine2-bin (1.2.8-2build2) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1) ...
# Setting up liborc-0.4-dev-bin (1:0.4.28-1) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up libxvidcore-dev:amd64 (2:1.3.5-1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up libfaac-dev:amd64 (1.29.7.7-1) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxine2-dev (1.2.8-2build2) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-11) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Setting up libmp3lame-dev:amd64 (3.100-2) ...
# Setting up libgpac4:amd64 (0.5.2-426-gc5ad4e4+dfsg5-3ubuntu0.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up wayland-protocols (1.13-1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libepoxy-dev:amd64 (1.4.3-1) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up gir1.2-atspi-2.0:amd64 (2.28.0-1) ...
# Setting up libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up gir1.2-gtk-3.0:amd64 (3.22.30-1ubuntu4) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libv4l-0:amd64 (1.14.2-1) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up x264 (2:0.152.2854+gite9a5903-2) ...
# Setting up v4l-utils (1.14.2-1) ...
# Setting up libopencore-amrnb-dev:amd64 (0.1.3-2.1) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up libatspi2.0-dev:amd64 (2.28.0-1) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up libatk-bridge2.0-dev:amd64 (2.26.2-1) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up liborc-0.4-dev (1:0.4.28-1) ...
# Setting up libv4l-dev:amd64 (1.14.2-1) ...
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libopencore-amrwb-dev:amd64 (0.1.3-2.1) ...
# Setting up gir1.2-gstreamer-1.0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libgtk-3-dev:amd64 (3.22.30-1ubuntu4) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up gir1.2-gst-plugins-base-1.0:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libgstreamer1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up libgstreamer-plugins-base1.0-dev:amd64 (1.14.5-0ubuntu1~18.04.1) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.6) ...
# 'Completed'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.listdir('/content/drive/My Drive/darknet/TwoClass/YOLO_Custom')
# Out:
# ['obj.names',
#  'obj.data',
#  'train.txt',
#  'test.txt',
#  'yolov3-tiny_obj_test.cfg',
#  'yolov3-tiny_obj_train.cfg',
#  'images',
#  'yolov3-tiny_obj_train_tiny8.weights',
#  'yolov3_train.cfg',
#  'yolov3_test.cfg']

# %% [markdown]
# ### Get Tiny YOLO Weight (Skip if Resuming Training)

# %%
# !wget --header="Host: pjreddie.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://github.com/AlexeyAB/darknet" --header="Cookie: __utma=134107727.1364647705.1589636782.1589689587.1589901067.3; __utmz=134107727.1589901067.3.3.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)" --header="Connection: keep-alive" "https://pjreddie.com/media/files/yolov3-tiny.weights" -c -O 'yolov3-tiny.weights'
# Out:
# --2020-05-27 16:38:37--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights  36%[======>             ]  12.41M   447KB/s    eta 1m 48s ^C

# %%
# !./darknet partial cfg/yolov3-tiny.cfg yolov3-tiny.weights yolov3-tiny.conv.15 15
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV version: 3.2.0
#  GPU isn't used
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max                2x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv    255       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 255 0.044 BF
#   16 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13 		                           ->   13 x  13 x 256
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8 	                           ->   26 x  26 x 384
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv    255       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 255 0.088 BF
#   23 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.571
# avg_outputs = 341534
# Loading weights from yolov3-tiny.weights...
#  seen 64, trained: 32013 K-images (500 Kilo-batches_64)
# Done! Loaded 15 layers from weights-file
# Saving weights to yolov3-tiny.conv.15

# %% [markdown]
# ### Copy Required Files from Drive

# %%
# Copy fils from Google Drive to the VM local filesystem
# !cp -r "/content/drive/My Drive/darknet/TwoClass/YOLO_Custom" /content/darknet/YOLO_Custom

# %% [markdown]
# ### Train

# %% [markdown]
# Use the below command to train yolo:
#
# !./darknet detector train data_file_path config_file_path training_weights_path log_path

# %% [markdown]
# To train yolov3 instead of tiny yolo, replace the following files:
#
# use ***yolov3_train_cfg*** instead of ***yolov3-tiny_obj_train.cfg***
# use ***yolov3_test_cfg*** instead of ***yolov3-tiny_obj_test.cfg*** for testing purpose.
# Replace the yolov3 weight link with the tiny yolo weight link

# %%
# Adding symbolic link
# !ln -s "/content/drive/My Drive/darknet/TwoClass/YOLO_Custom" /content/darknet/YOLO_Custom/backup
# Out:
# ln: failed to create symbolic link '/content/darknet/YOLO_Custom/backup/YOLO_Custom': File exists

# %%
# !./darknet detector train "/content/darknet/YOLO_Custom/obj.data" "/content/darknet/YOLO_Custom/yolov3-tiny_obj_train.cfg" "/content/darknet/YOLO_Custom/yolov3-tiny_obj_train_tiny8.weights" "train.log" -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.598229, GIOU: 0.556308), Class: 0.960993, Obj: 0.413647, No Obj: 0.000654, .5R: 0.750000, .75R: 0.500000, count: 4, class_loss = 0.567376, iou_loss = 0.228211, total_loss = 0.795587
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.800903, GIOU: 0.794531), Class: 0.999997, Obj: 0.853128, No Obj: 0.001220, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.022083, iou_loss = 0.041314, total_loss = 0.063397
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.634320, GIOU: 0.593610), Class: 0.951071, Obj: 0.440125, No Obj: 0.000697, .5R: 0.750000, .75R: 0.250000, count: 4, class_loss = 0.527306, iou_loss = 0.498518, total_loss = 1.025824
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.803446, GIOU: 0.803446), Class: 0.999938, Obj: 0.990608, No Obj: 0.000792, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.002042, iou_loss = 0.012510, total_loss = 0.014552
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.599102, GIOU: 0.553659), Class: 0.993221, Obj: 0.798287, No Obj: 0.000503, .5R: 0.666667, .75R: 0.333333, count: 3, class_loss = 0.063153, iou_loss = 0.193736, total_loss = 0.256890
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.498513, GIOU: 0.498513), Class: 0.937598, Obj: 0.006843, No Obj: 0.000806, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.337672, iou_loss = 0.136974, total_loss = 0.474646
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.714909, GIOU: 0.701290), Class: 0.997914, Obj: 0.629775, No Obj: 0.001838, .5R: 0.916667, .75R: 0.583333, count: 12, class_loss = 0.953429, iou_loss = 0.684355, total_loss = 1.637784
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.826383, GIOU: 0.825081), Class: 0.994100, Obj: 0.695738, No Obj: 0.002557, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.071751, iou_loss = 0.028327, total_loss = 0.100078
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.748550, GIOU: 0.734071), Class: 0.995239, Obj: 0.479129, No Obj: 0.000887, .5R: 1.000000, .75R: 0.600000, count: 5, class_loss = 0.949695, iou_loss = 0.244633, total_loss = 1.194328
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.815774, GIOU: 0.813671), Class: 0.999997, Obj: 0.889869, No Obj: 0.001427, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.006457, iou_loss = 0.044530, total_loss = 0.050987
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.693867, GIOU: 0.676059), Class: 0.945897, Obj: 0.410768, No Obj: 0.002239, .5R: 1.000000, .75R: 0.285714, count: 14, class_loss = 2.252432, iou_loss = 0.726818, total_loss = 2.979250
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.790321, GIOU: 0.779237), Class: 0.999962, Obj: 0.897634, No Obj: 0.003442, .5R: 1.000000, .75R: 0.600000, count: 5, class_loss = 0.055291, iou_loss = 0.150695, total_loss = 0.205986
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.663212, GIOU: 0.645511), Class: 0.967018, Obj: 0.500979, No Obj: 0.000822, .5R: 0.800000, .75R: 0.400000, count: 5, class_loss = 0.728957, iou_loss = 0.408857, total_loss = 1.137814
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.857552, GIOU: 0.853065), Class: 0.999908, Obj: 0.971557, No Obj: 0.001043, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.004984, iou_loss = 0.010743, total_loss = 0.015727
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.636451, GIOU: 0.607908), Class: 0.962346, Obj: 0.551833, No Obj: 0.003441, .5R: 0.750000, .75R: 0.375000, count: 24, class_loss = 2.761710, iou_loss = 1.194979, total_loss = 3.956688
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.773545, GIOU: 0.769807), Class: 0.999319, Obj: 0.589429, No Obj: 0.002593, .5R: 1.000000, .75R: 0.500000, count: 4, class_loss = 0.417456, iou_loss = 0.154856, total_loss = 0.572312
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.513464, GIOU: 0.513464), Class: 1.000000, Obj: 0.746395, No Obj: 0.000371, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.063192, iou_loss = 0.145675, total_loss = 0.208868
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.770017, GIOU: 0.760627), Class: 0.998604, Obj: 0.705606, No Obj: 0.002372, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.079653, iou_loss = 0.061329, total_loss = 0.140982
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.714065, GIOU: 0.703345), Class: 0.945616, Obj: 0.576568, No Obj: 0.002643, .5R: 1.000000, .75R: 0.533333, count: 15, class_loss = 1.663066, iou_loss = 0.857436, total_loss = 2.520502
#
#  6168: 1.182954, 1.104434 avg loss, 0.000010 rate, 0.860841 seconds, 394752 images, 14101.078613 hours left
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.774356, GIOU: 0.764870), Class: 0.993991, Obj: 0.638139, No Obj: 0.001478, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.082979, iou_loss = 0.065004, total_loss = 0.147982
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.813586, GIOU: 0.810928), Class: 0.999819, Obj: 0.685353, No Obj: 0.000826, .5R: 1.000000, .75R: 0.750000, count: 4, class_loss = 0.285166, iou_loss = 0.100021, total_loss = 0.385187
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.817131, GIOU: 0.815051), Class: 0.999985, Obj: 0.399389, No Obj: 0.000961, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.123206, iou_loss = 0.033990, total_loss = 0.157196
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.684158, GIOU: 0.663278), Class: 0.997526, Obj: 0.473970, No Obj: 0.000652, .5R: 1.000000, .75R: 0.250000, count: 4, class_loss = 0.483713, iou_loss = 0.318564, total_loss = 0.802277
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.692355, GIOU: 0.662976), Class: 0.999993, Obj: 0.568292, No Obj: 0.000873, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.247615, iou_loss = 0.219925, total_loss = 0.467540
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.636142, GIOU: 0.618703), Class: 0.975168, Obj: 0.760266, No Obj: 0.001156, .5R: 0.833333, .75R: 0.333333, count: 6, class_loss = 0.327352, iou_loss = 0.228026, total_loss = 0.555377
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.627555, GIOU: 0.627555), Class: 0.999815, Obj: 0.765059, No Obj: 0.000953, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.024322, iou_loss = 0.068311, total_loss = 0.092633
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.633797, GIOU: 0.604126), Class: 0.980629, Obj: 0.387242, No Obj: 0.001093, .5R: 0.750000, .75R: 0.250000, count: 8, class_loss = 1.395374, iou_loss = 0.737776, total_loss = 2.133150
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.830972, GIOU: 0.824836), Class: 0.999559, Obj: 0.247907, No Obj: 0.000742, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.307626, iou_loss = 0.047783, total_loss = 0.355409
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.681416, GIOU: 0.663343), Class: 0.987976, Obj: 0.625528, No Obj: 0.001694, .5R: 0.818182, .75R: 0.454545, count: 11, class_loss = 0.968471, iou_loss = 0.462364, total_loss = 1.430835
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.770370, GIOU: 0.765526), Class: 0.999441, Obj: 0.865912, No Obj: 0.002722, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.257798, iou_loss = 0.136383, total_loss = 0.394182
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.643126, GIOU: 0.618129), Class: 0.999071, Obj: 0.236254, No Obj: 0.000137, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.306685, iou_loss = 0.182301, total_loss = 0.488986
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.872853, GIOU: 0.872049), Class: 0.999997, Obj: 0.964476, No Obj: 0.000947, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000321, iou_loss = 0.022815, total_loss = 0.023136
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.754588, GIOU: 0.749772), Class: 0.997171, Obj: 0.639359, No Obj: 0.000931, .5R: 1.000000, .75R: 0.600000, count: 5, class_loss = 0.567912, iou_loss = 0.177145, total_loss = 0.745057
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000053, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000761, iou_loss = 0.000000, total_loss = 0.000761
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.612343, GIOU: 0.588600), Class: 0.970509, Obj: 0.302947, No Obj: 0.000865, .5R: 0.857143, .75R: 0.142857, count: 7, class_loss = 1.156981, iou_loss = 0.791021, total_loss = 1.948002
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.777995, GIOU: 0.773548), Class: 0.999905, Obj: 0.615911, No Obj: 0.000627, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.058929, iou_loss = 0.018761, total_loss = 0.077690
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.636737, GIOU: 0.618927), Class: 0.998486, Obj: 0.770118, No Obj: 0.001324, .5R: 1.000000, .75R: 0.166667, count: 6, class_loss = 0.427188, iou_loss = 0.289916, total_loss = 0.717105
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000312, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001888, iou_loss = 0.000000, total_loss = 0.001888
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.656664, GIOU: 0.635758), Class: 0.943522, Obj: 0.532672, No Obj: 0.003168, .5R: 0.909091, .75R: 0.272727, count: 22, class_loss = 2.493498, iou_loss = 1.402363, total_loss = 3.895860
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000103, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.001480, iou_loss = 0.000000, total_loss = 0.001480
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.655516, GIOU: 0.637197), Class: 0.928003, Obj: 0.493033, No Obj: 0.001747, .5R: 0.916667, .75R: 0.083333, count: 12, class_loss = 1.830512, iou_loss = 0.844555, total_loss = 2.675066
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.873445, GIOU: 0.869047), Class: 0.999951, Obj: 0.958879, No Obj: 0.001117, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.006160, iou_loss = 0.013095, total_loss = 0.019255
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.696475, GIOU: 0.675327), Class: 0.970806, Obj: 0.477274, No Obj: 0.001448, .5R: 0.900000, .75R: 0.300000, count: 10, class_loss = 1.447946, iou_loss = 0.599118, total_loss = 2.047064
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.678974, GIOU: 0.675904), Class: 0.999716, Obj: 0.947337, No Obj: 0.000620, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.000792, iou_loss = 0.069214, total_loss = 0.070007
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.589901, GIOU: 0.557245), Class: 0.927803, Obj: 0.448735, No Obj: 0.002997, .5R: 0.684211, .75R: 0.368421, count: 19, class_loss = 3.069260, iou_loss = 1.920408, total_loss = 4.989667
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.928213, GIOU: 0.927542), Class: 0.999954, Obj: 0.891666, No Obj: 0.000985, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.027953, iou_loss = 0.002850, total_loss = 0.030803
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.630184, GIOU: 0.599442), Class: 0.935486, Obj: 0.614451, No Obj: 0.005207, .5R: 0.777778, .75R: 0.388889, count: 36, class_loss = 3.799956, iou_loss = 2.947676, total_loss = 6.747632
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.706085, GIOU: 0.704467), Class: 0.999597, Obj: 0.566298, No Obj: 0.000861, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.181414, iou_loss = 0.124709, total_loss = 0.306123
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.428811, GIOU: 0.343245), Class: 0.957641, Obj: 0.536381, No Obj: 0.002620, .5R: 0.444444, .75R: 0.222222, count: 18, class_loss = 1.990203, iou_loss = 1.233239, total_loss = 3.223442
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.758707, GIOU: 0.748543), Class: 0.999621, Obj: 0.693970, No Obj: 0.003142, .5R: 1.000000, .75R: 0.500000, count: 4, class_loss = 0.184481, iou_loss = 0.370237, total_loss = 0.554718
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.773843, GIOU: 0.767716), Class: 0.998993, Obj: 0.596835, No Obj: 0.000558, .5R: 1.000000, .75R: 0.333333, count: 3, class_loss = 0.255300, iou_loss = 0.123848, total_loss = 0.379148
#
#  6169: 1.120770, 1.106068 avg loss, 0.000010 rate, 0.858168 seconds, 394816 images, 14079.669412 hours left
# Loaded: 0.000037 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000015, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000033, iou_loss = 0.000000, total_loss = 0.000033
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.791407, GIOU: 0.785504), Class: 0.998829, Obj: 0.813752, No Obj: 0.001311, .5R: 1.000000, .75R: 0.714286, count: 7, class_loss = 0.252522, iou_loss = 0.117700, total_loss = 0.370222
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.710202, GIOU: 0.700535), Class: 0.999187, Obj: 0.473562, No Obj: 0.000708, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.234962, iou_loss = 0.100593, total_loss = 0.335555
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.771365, GIOU: 0.764628), Class: 0.970872, Obj: 0.598906, No Obj: 0.001988, .5R: 1.000000, .75R: 0.666667, count: 9, class_loss = 0.841051, iou_loss = 0.356881, total_loss = 1.197932
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.816706, GIOU: 0.813301), Class: 0.999046, Obj: 0.981455, No Obj: 0.001173, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.016260, iou_loss = 0.034149, total_loss = 0.050408
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.694157, GIOU: 0.681037), Class: 0.970596, Obj: 0.433269, No Obj: 0.000617, .5R: 1.000000, .75R: 0.333333, count: 6, class_loss = 0.748567, iou_loss = 0.455422, total_loss = 1.203988
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.795476, GIOU: 0.791354), Class: 1.000000, Obj: 0.995718, No Obj: 0.000604, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000033, iou_loss = 0.017252, total_loss = 0.017285
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.687607, GIOU: 0.659182), Class: 0.992468, Obj: 0.673840, No Obj: 0.000562, .5R: 1.000000, .75R: 0.000000, count: 3, class_loss = 0.320524, iou_loss = 0.190930, total_loss = 0.511454
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.845870, GIOU: 0.843170), Class: 0.999997, Obj: 0.582756, No Obj: 0.001999, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.188689, iou_loss = 0.042210, total_loss = 0.230899
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.768931, GIOU: 0.761764), Class: 0.995721, Obj: 0.823884, No Obj: 0.000651, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.220803, iou_loss = 0.125056, total_loss = 0.345859
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.855554, GIOU: 0.854233), Class: 0.987305, Obj: 0.607004, No Obj: 0.001970, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.160302, iou_loss = 0.019318, total_loss = 0.179620
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.577769, GIOU: 0.522223), Class: 0.987634, Obj: 0.614441, No Obj: 0.001907, .5R: 0.666667, .75R: 0.250000, count: 12, class_loss = 0.926122, iou_loss = 0.854703, total_loss = 1.780825
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000086, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000736, iou_loss = 0.000000, total_loss = 0.000736
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.756834, GIOU: 0.748593), Class: 0.997673, Obj: 0.662251, No Obj: 0.003199, .5R: 0.947368, .75R: 0.736842, count: 19, class_loss = 1.292642, iou_loss = 0.794711, total_loss = 2.087353
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.679192, GIOU: 0.669416), Class: 0.986216, Obj: 0.496078, No Obj: 0.001396, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.289081, iou_loss = 0.150673, total_loss = 0.439755
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.603496, GIOU: 0.573726), Class: 0.944573, Obj: 0.585009, No Obj: 0.000834, .5R: 0.666667, .75R: 0.166667, count: 6, class_loss = 0.629953, iou_loss = 0.313989, total_loss = 0.943943
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.617257, GIOU: 0.617257), Class: 0.999931, Obj: 0.467481, No Obj: 0.001084, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.252147, iou_loss = 0.072414, total_loss = 0.324561
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.746034, GIOU: 0.727732), Class: 0.999285, Obj: 0.545638, No Obj: 0.000532, .5R: 1.000000, .75R: 0.333333, count: 3, class_loss = 0.274817, iou_loss = 0.147213, total_loss = 0.422030
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.840299, GIOU: 0.835425), Class: 0.999953, Obj: 0.902716, No Obj: 0.002917, .5R: 1.000000, .75R: 1.000000, count: 4, class_loss = 0.022165, iou_loss = 0.067314, total_loss = 0.089480
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.740277, GIOU: 0.729620), Class: 0.913735, Obj: 0.579358, No Obj: 0.000465, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.193273, iou_loss = 0.081707, total_loss = 0.274980
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000142, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000006, iou_loss = 0.000000, total_loss = 0.000006
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.761212, GIOU: 0.748834), Class: 0.996592, Obj: 0.744683, No Obj: 0.002584, .5R: 1.000000, .75R: 0.533333, count: 15, class_loss = 1.137256, iou_loss = 0.583498, total_loss = 1.720754
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.828906, GIOU: 0.823467), Class: 0.999982, Obj: 0.872907, No Obj: 0.003359, .5R: 1.000000, .75R: 1.000000, count: 4, class_loss = 0.105628, iou_loss = 0.104850, total_loss = 0.210478
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.767728, GIOU: 0.757190), Class: 0.998573, Obj: 0.586466, No Obj: 0.000827, .5R: 1.000000, .75R: 0.600000, count: 5, class_loss = 0.596560, iou_loss = 0.201331, total_loss = 0.797891
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.932917, GIOU: 0.932917), Class: 0.999856, Obj: 0.952820, No Obj: 0.001213, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000558, iou_loss = 0.002516, total_loss = 0.003074
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.784549, GIOU: 0.778184), Class: 0.997480, Obj: 0.331503, No Obj: 0.000698, .5R: 1.000000, .75R: 0.833333, count: 6, class_loss = 1.042783, iou_loss = 0.169828, total_loss = 1.212611
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.764174, GIOU: 0.754652), Class: 0.999721, Obj: 0.847261, No Obj: 0.002889, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.244706, iou_loss = 0.082754, total_loss = 0.327460
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.833399, GIOU: 0.826487), Class: 0.999994, Obj: 0.981505, No Obj: 0.000322, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000851, iou_loss = 0.013212, total_loss = 0.014063
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.831216, GIOU: 0.827388), Class: 0.999910, Obj: 0.570576, No Obj: 0.001500, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.337215, iou_loss = 0.038750, total_loss = 0.375965
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.652420, GIOU: 0.630837), Class: 0.990983, Obj: 0.746322, No Obj: 0.001509, .5R: 0.777778, .75R: 0.444444, count: 9, class_loss = 0.702210, iou_loss = 0.478694, total_loss = 1.180904
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.848315, GIOU: 0.841166), Class: 0.999888, Obj: 0.959196, No Obj: 0.003326, .5R: 1.000000, .75R: 0.750000, count: 4, class_loss = 0.022975, iou_loss = 0.079330, total_loss = 0.102304
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.704468, GIOU: 0.692479), Class: 0.997895, Obj: 0.825158, No Obj: 0.000306, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.015430, iou_loss = 0.040785, total_loss = 0.056214
#
#  6170: 0.525270, 1.047988 avg loss, 0.000010 rate, 0.862343 seconds, 394880 images, 14058.105973 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 17.84 MB
#  CUDA allocate done!
# Loaded: 0.430147 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000021, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000023, iou_loss = 0.000000, total_loss = 0.000023
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.569008, GIOU: 0.529562), Class: 0.952575, Obj: 0.604939, No Obj: 0.002238, .5R: 0.750000, .75R: 0.166667, count: 12, class_loss = 1.372965, iou_loss = 0.857599, total_loss = 2.230564
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.686910, GIOU: 0.679554), Class: 0.987867, Obj: 0.671088, No Obj: 0.003408, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.374610, iou_loss = 0.116530, total_loss = 0.491140
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.771241, GIOU: 0.764325), Class: 0.988221, Obj: 0.672195, No Obj: 0.001637, .5R: 1.000000, .75R: 0.750000, count: 8, class_loss = 0.672435, iou_loss = 0.427302, total_loss = 1.099736
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.847768, GIOU: 0.841103), Class: 0.999997, Obj: 0.988753, No Obj: 0.001906, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.000182, iou_loss = 0.039726, total_loss = 0.039908
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.668685, GIOU: 0.648671), Class: 0.957231, Obj: 0.444082, No Obj: 0.003924, .5R: 0.850000, .75R: 0.300000, count: 20, class_loss = 3.233619, iou_loss = 1.253260, total_loss = 4.486879
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.768941, GIOU: 0.756447), Class: 0.999951, Obj: 0.834105, No Obj: 0.001408, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.051502, iou_loss = 0.049483, total_loss = 0.100985
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.688035, GIOU: 0.651779), Class: 0.976062, Obj: 0.616742, No Obj: 0.002424, .5R: 0.800000, .75R: 0.600000, count: 10, class_loss = 1.044803, iou_loss = 0.341934, total_loss = 1.386737
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000907, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.190065, iou_loss = 0.000000, total_loss = 0.190065
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.725889, GIOU: 0.709355), Class: 0.969663, Obj: 0.635348, No Obj: 0.001762, .5R: 1.000000, .75R: 0.400000, count: 10, class_loss = 0.678234, iou_loss = 0.643970, total_loss = 1.322204
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.695971, GIOU: 0.676973), Class: 0.999173, Obj: 0.785677, No Obj: 0.002203, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.080126, iou_loss = 0.104646, total_loss = 0.184772
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.656008, GIOU: 0.601095), Class: 0.999370, Obj: 0.552809, No Obj: 0.001542, .5R: 0.888889, .75R: 0.666667, count: 9, class_loss = 0.874129, iou_loss = 0.518767, total_loss = 1.392897
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.772189, GIOU: 0.766914), Class: 0.999269, Obj: 0.514116, No Obj: 0.003350, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.331676, iou_loss = 0.115270, total_loss = 0.446946
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.744489, GIOU: 0.737721), Class: 0.944426, Obj: 0.500212, No Obj: 0.001091, .5R: 1.000000, .75R: 0.500000, count: 6, class_loss = 0.821106, iou_loss = 0.328825, total_loss = 1.149931
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.779874, GIOU: 0.772263), Class: 0.999917, Obj: 0.917267, No Obj: 0.004537, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.136436, iou_loss = 0.101315, total_loss = 0.237751
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.745754, GIOU: 0.743473), Class: 0.992707, Obj: 0.483181, No Obj: 0.000713, .5R: 1.000000, .75R: 0.500000, count: 4, class_loss = 0.413702, iou_loss = 0.247351, total_loss = 0.661053
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.847966, GIOU: 0.845824), Class: 0.993069, Obj: 0.410764, No Obj: 0.002659, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.434811, iou_loss = 0.077114, total_loss = 0.511925
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.738707, GIOU: 0.720625), Class: 0.999654, Obj: 0.504008, No Obj: 0.000289, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.065546, iou_loss = 0.042372, total_loss = 0.107919
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.792482, GIOU: 0.789783), Class: 0.989123, Obj: 0.873077, No Obj: 0.004542, .5R: 1.000000, .75R: 0.750000, count: 4, class_loss = 0.025354, iou_loss = 0.080677, total_loss = 0.106031
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.585561, GIOU: 0.486066), Class: 0.783511, Obj: 0.310100, No Obj: 0.000945, .5R: 0.800000, .75R: 0.200000, count: 5, class_loss = 1.189945, iou_loss = 1.945597, total_loss = 3.135542
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.864810, GIOU: 0.864721), Class: 0.994990, Obj: 0.902951, No Obj: 0.002070, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.019055, iou_loss = 0.038006, total_loss = 0.057062
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.715651, GIOU: 0.696726), Class: 0.998111, Obj: 0.844714, No Obj: 0.000680, .5R: 1.000000, .75R: 0.333333, count: 3, class_loss = 0.048509, iou_loss = 0.176252, total_loss = 0.224762
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000087, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000277, iou_loss = 0.000000, total_loss = 0.000277
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.700278, GIOU: 0.688461), Class: 0.933551, Obj: 0.689895, No Obj: 0.001181, .5R: 0.833333, .75R: 0.500000, count: 6, class_loss = 0.410005, iou_loss = 0.265276, total_loss = 0.675281
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.891035, GIOU: 0.887937), Class: 0.999863, Obj: 0.894585, No Obj: 0.001061, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.039045, iou_loss = 0.011646, total_loss = 0.050691
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.580166, GIOU: 0.542805), Class: 0.923161, Obj: 0.343027, No Obj: 0.002910, .5R: 0.700000, .75R: 0.250000, count: 20, class_loss = 3.347627, iou_loss = 2.097405, total_loss = 5.445033
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.803347, GIOU: 0.803056), Class: 0.999288, Obj: 0.442622, No Obj: 0.003521, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.238007, iou_loss = 0.082455, total_loss = 0.320462
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.782990, GIOU: 0.779609), Class: 0.997554, Obj: 0.658950, No Obj: 0.001987, .5R: 0.909091, .75R: 0.818182, count: 11, class_loss = 0.915620, iou_loss = 0.716041, total_loss = 1.631661
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.910226, GIOU: 0.909104), Class: 1.000000, Obj: 0.978301, No Obj: 0.001134, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000511, iou_loss = 0.007120, total_loss = 0.007631
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.654319, GIOU: 0.634604), Class: 0.987081, Obj: 0.725050, No Obj: 0.001826, .5R: 0.888889, .75R: 0.333333, count: 9, class_loss = 0.530829, iou_loss = 0.599544, total_loss = 1.130373
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.680329, GIOU: 0.667728), Class: 0.998981, Obj: 0.544819, No Obj: 0.001284, .5R: 1.000000, .75R: 0.000000, count: 3, class_loss = 0.216058, iou_loss = 0.202774, total_loss = 0.418832
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.509984, GIOU: 0.449154), Class: 0.986932, Obj: 0.601953, No Obj: 0.005416, .5R: 0.555556, .75R: 0.185185, count: 27, class_loss = 2.459185, iou_loss = 2.626735, total_loss = 5.085920
#
#  6171: 1.072844, 1.050473 avg loss, 0.000010 rate, 0.733565 seconds, 394944 images, 14037.336094 hours left
# Loaded: 0.000063 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000083, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000461, iou_loss = 0.000000, total_loss = 0.000461
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.638552, GIOU: 0.608301), Class: 0.947738, Obj: 0.516330, No Obj: 0.004079, .5R: 0.760000, .75R: 0.280000, count: 25, class_loss = 2.875051, iou_loss = 1.579833, total_loss = 4.454883
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.592990, GIOU: 0.573928), Class: 0.955585, Obj: 0.541219, No Obj: 0.001973, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.128438, iou_loss = 0.220642, total_loss = 0.349080
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.588548, GIOU: 0.549965), Class: 0.978331, Obj: 0.461769, No Obj: 0.001683, .5R: 0.777778, .75R: 0.222222, count: 9, class_loss = 1.313558, iou_loss = 0.845921, total_loss = 2.159479
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.884412, GIOU: 0.883318), Class: 0.999979, Obj: 0.974784, No Obj: 0.001966, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000160, iou_loss = 0.007131, total_loss = 0.007291
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.596972, GIOU: 0.568044), Class: 0.970320, Obj: 0.570818, No Obj: 0.001663, .5R: 0.900000, .75R: 0.100000, count: 10, class_loss = 1.179148, iou_loss = 0.851670, total_loss = 2.030818
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.784160, GIOU: 0.780775), Class: 0.999967, Obj: 0.539144, No Obj: 0.002234, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.202821, iou_loss = 0.063958, total_loss = 0.266779
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.832338, GIOU: 0.829103), Class: 0.989664, Obj: 0.851993, No Obj: 0.000793, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.055599, iou_loss = 0.056013, total_loss = 0.111612
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.935634, GIOU: 0.935472), Class: 0.998102, Obj: 0.817655, No Obj: 0.001981, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.093062, iou_loss = 0.006454, total_loss = 0.099516
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.738271, GIOU: 0.726293), Class: 0.997196, Obj: 0.646180, No Obj: 0.001880, .5R: 1.000000, .75R: 0.444444, count: 9, class_loss = 0.918730, iou_loss = 0.431122, total_loss = 1.349852
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.786833, GIOU: 0.786833), Class: 0.999996, Obj: 0.970078, No Obj: 0.001909, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.004703, iou_loss = 0.017200, total_loss = 0.021904
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.787765, GIOU: 0.780466), Class: 0.995563, Obj: 0.737242, No Obj: 0.001625, .5R: 1.000000, .75R: 0.500000, count: 8, class_loss = 0.207406, iou_loss = 0.299810, total_loss = 0.507216
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.910360, GIOU: 0.909582), Class: 0.999909, Obj: 0.964037, No Obj: 0.001421, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.001970, iou_loss = 0.011772, total_loss = 0.013742
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.724669, GIOU: 0.703647), Class: 0.983217, Obj: 0.564641, No Obj: 0.002939, .5R: 0.833333, .75R: 0.583333, count: 12, class_loss = 1.098475, iou_loss = 0.811353, total_loss = 1.909828
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.876022, GIOU: 0.876022), Class: 0.993835, Obj: 0.932557, No Obj: 0.000767, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.001166, iou_loss = 0.005884, total_loss = 0.007050
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.614080, GIOU: 0.582808), Class: 0.930978, Obj: 0.517185, No Obj: 0.004972, .5R: 0.814815, .75R: 0.333333, count: 27, class_loss = 3.388556, iou_loss = 2.589349, total_loss = 5.977905
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.780574, GIOU: 0.774631), Class: 0.999777, Obj: 0.682377, No Obj: 0.002477, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.348873, iou_loss = 0.139558, total_loss = 0.488431
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.748198, GIOU: 0.738188), Class: 0.971035, Obj: 0.582047, No Obj: 0.001380, .5R: 1.000000, .75R: 0.428571, count: 7, class_loss = 0.740256, iou_loss = 0.320638, total_loss = 1.060894
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.896621, GIOU: 0.894546), Class: 1.000000, Obj: 0.941517, No Obj: 0.000986, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.007492, iou_loss = 0.003784, total_loss = 0.011276
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.709129, GIOU: 0.688600), Class: 0.992011, Obj: 0.577019, No Obj: 0.002884, .5R: 0.933333, .75R: 0.400000, count: 15, class_loss = 1.246283, iou_loss = 0.766386, total_loss = 2.012669
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.815148, GIOU: 0.813591), Class: 0.999390, Obj: 0.964867, No Obj: 0.001196, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.091771, iou_loss = 0.020863, total_loss = 0.112634
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.494422, GIOU: 0.445470), Class: 0.928087, Obj: 0.479150, No Obj: 0.003246, .5R: 0.538462, .75R: 0.038462, count: 26, class_loss = 2.925564, iou_loss = 3.039657, total_loss = 5.965221
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.829123, GIOU: 0.826805), Class: 0.999976, Obj: 0.729932, No Obj: 0.003291, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.341975, iou_loss = 0.069544, total_loss = 0.411519
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.726943, GIOU: 0.724806), Class: 0.999990, Obj: 0.976874, No Obj: 0.000369, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.000474, iou_loss = 0.043047, total_loss = 0.043520
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.790529, GIOU: 0.782897), Class: 0.999863, Obj: 0.930238, No Obj: 0.001233, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.006813, iou_loss = 0.039554, total_loss = 0.046368
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.556396, GIOU: 0.530839), Class: 0.936126, Obj: 0.758765, No Obj: 0.001990, .5R: 0.777778, .75R: 0.222222, count: 9, class_loss = 0.546053, iou_loss = 0.343811, total_loss = 0.889864
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.757851, GIOU: 0.757851), Class: 0.999985, Obj: 0.946420, No Obj: 0.001525, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.001651, iou_loss = 0.071545, total_loss = 0.073196
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.806537, GIOU: 0.802265), Class: 0.999832, Obj: 0.803827, No Obj: 0.004012, .5R: 1.000000, .75R: 0.882353, count: 17, class_loss = 0.940388, iou_loss = 0.394565, total_loss = 1.334953
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.849176, GIOU: 0.842537), Class: 0.999949, Obj: 0.250385, No Obj: 0.001139, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.240202, iou_loss = 0.008475, total_loss = 0.248677
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.754186, GIOU: 0.747381), Class: 0.996959, Obj: 0.279053, No Obj: 0.000841, .5R: 1.000000, .75R: 0.500000, count: 6, class_loss = 0.857320, iou_loss = 0.355291, total_loss = 1.212611
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.854720, GIOU: 0.852924), Class: 0.999975, Obj: 0.837745, No Obj: 0.001275, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.024029, iou_loss = 0.024441, total_loss = 0.048470
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.643888, GIOU: 0.614061), Class: 0.991135, Obj: 0.556739, No Obj: 0.005764, .5R: 0.741935, .75R: 0.258065, count: 31, class_loss = 3.869443, iou_loss = 1.812136, total_loss = 5.681579
#
#  6172: 1.215915, 1.067018 avg loss, 0.000010 rate, 0.712608 seconds, 395008 images, 14058.636922 hours left
# Loaded: 0.000035 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.824059, GIOU: 0.819560), Class: 0.999807, Obj: 0.672174, No Obj: 0.002697, .5R: 1.000000, .75R: 1.000000, count: 4, class_loss = 0.370514, iou_loss = 0.088320, total_loss = 0.458833
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.614217, GIOU: 0.575304), Class: 0.988384, Obj: 0.612872, No Obj: 0.000957, .5R: 0.600000, .75R: 0.400000, count: 5, class_loss = 0.452246, iou_loss = 0.677493, total_loss = 1.129738
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.755890, GIOU: 0.737557), Class: 0.951791, Obj: 0.105189, No Obj: 0.000399, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.202660, iou_loss = 0.027819, total_loss = 0.230479
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.604569, GIOU: 0.546072), Class: 0.866497, Obj: 0.481453, No Obj: 0.000931, .5R: 0.833333, .75R: 0.333333, count: 6, class_loss = 0.872387, iou_loss = 0.846542, total_loss = 1.718928
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.763015, GIOU: 0.750190), Class: 0.992106, Obj: 0.634762, No Obj: 0.001834, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.120857, iou_loss = 0.122160, total_loss = 0.243017
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.786088, GIOU: 0.777136), Class: 0.983315, Obj: 0.815755, No Obj: 0.002727, .5R: 1.000000, .75R: 0.727273, count: 11, class_loss = 0.655183, iou_loss = 0.355227, total_loss = 1.010410
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000244, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000010, iou_loss = 0.000000, total_loss = 0.000010
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.670536, GIOU: 0.642871), Class: 0.949526, Obj: 0.633430, No Obj: 0.003490, .5R: 0.888889, .75R: 0.388889, count: 18, class_loss = 1.524382, iou_loss = 0.926991, total_loss = 2.451374
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000048, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000682, iou_loss = 0.000000, total_loss = 0.000682
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.519082, GIOU: 0.467719), Class: 0.873987, Obj: 0.476645, No Obj: 0.001735, .5R: 0.500000, .75R: 0.083333, count: 12, class_loss = 2.070588, iou_loss = 0.999254, total_loss = 3.069842
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.785844, GIOU: 0.785843), Class: 0.999997, Obj: 0.959814, No Obj: 0.001707, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.175339, iou_loss = 0.038273, total_loss = 0.213612
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.806407, GIOU: 0.799912), Class: 0.999229, Obj: 0.786481, No Obj: 0.002193, .5R: 1.000000, .75R: 0.875000, count: 8, class_loss = 0.387597, iou_loss = 0.266751, total_loss = 0.654348
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.819517, GIOU: 0.819517), Class: 0.999967, Obj: 0.986198, No Obj: 0.002152, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.032036, iou_loss = 0.055069, total_loss = 0.087105
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.692710, GIOU: 0.684144), Class: 0.999612, Obj: 0.746345, No Obj: 0.000532, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.053247, iou_loss = 0.231012, total_loss = 0.284259
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.769995, GIOU: 0.759497), Class: 0.999870, Obj: 0.664749, No Obj: 0.001772, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.186645, iou_loss = 0.087886, total_loss = 0.274531
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.489654, GIOU: 0.444138), Class: 0.956923, Obj: 0.667242, No Obj: 0.001093, .5R: 0.750000, .75R: 0.000000, count: 4, class_loss = 0.319418, iou_loss = 0.521032, total_loss = 0.840450
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.910364, GIOU: 0.909006), Class: 0.999974, Obj: 0.959666, No Obj: 0.002105, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.057962, iou_loss = 0.007701, total_loss = 0.065663
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.487916, GIOU: 0.429755), Class: 0.979572, Obj: 0.674071, No Obj: 0.001648, .5R: 0.555556, .75R: 0.222222, count: 9, class_loss = 0.674121, iou_loss = 0.565289, total_loss = 1.239411
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000477, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.037528, iou_loss = 0.000000, total_loss = 0.037528
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.638044, GIOU: 0.606259), Class: 0.964856, Obj: 0.520275, No Obj: 0.005747, .5R: 0.781250, .75R: 0.375000, count: 32, class_loss = 3.740427, iou_loss = 2.046779, total_loss = 5.787207
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.856453, GIOU: 0.854319), Class: 0.999584, Obj: 0.525910, No Obj: 0.000996, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.189550, iou_loss = 0.026495, total_loss = 0.216044
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.517923, GIOU: 0.460445), Class: 0.903039, Obj: 0.492897, No Obj: 0.004620, .5R: 0.518519, .75R: 0.296296, count: 27, class_loss = 3.636501, iou_loss = 2.433256, total_loss = 6.069757
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000996, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.124204, iou_loss = 0.000000, total_loss = 0.124204
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.714021, GIOU: 0.699765), Class: 0.996926, Obj: 0.529838, No Obj: 0.001491, .5R: 1.000000, .75R: 0.428571, count: 7, class_loss = 0.826679, iou_loss = 0.484097, total_loss = 1.310776
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.772211, GIOU: 0.772160), Class: 0.998285, Obj: 0.606433, No Obj: 0.002586, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.182122, iou_loss = 0.114514, total_loss = 0.296636
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.775308, GIOU: 0.768683), Class: 0.740881, Obj: 0.113639, No Obj: 0.000471, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.990465, iou_loss = 0.112036, total_loss = 1.102501
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.827220, GIOU: 0.819535), Class: 0.999891, Obj: 0.779061, No Obj: 0.002027, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.107831, iou_loss = 0.048070, total_loss = 0.155901
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.726276, GIOU: 0.711538), Class: 0.960334, Obj: 0.339361, No Obj: 0.001023, .5R: 1.000000, .75R: 0.400000, count: 5, class_loss = 1.122832, iou_loss = 0.211417, total_loss = 1.334249
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.810086, GIOU: 0.804833), Class: 0.999854, Obj: 0.796968, No Obj: 0.000728, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.014395, iou_loss = 0.026327, total_loss = 0.040721
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.729211, GIOU: 0.717863), Class: 0.865626, Obj: 0.539886, No Obj: 0.001391, .5R: 0.875000, .75R: 0.750000, count: 8, class_loss = 1.262443, iou_loss = 0.356011, total_loss = 1.618455
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.714267, GIOU: 0.714267), Class: 0.999896, Obj: 0.388229, No Obj: 0.001779, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.169269, iou_loss = 0.049092, total_loss = 0.218362
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.516927, GIOU: 0.479810), Class: 0.930928, Obj: 0.530255, No Obj: 0.002168, .5R: 0.642857, .75R: 0.214286, count: 14, class_loss = 1.554452, iou_loss = 0.928788, total_loss = 2.483240
#
#  6173: 1.086509, 1.068967 avg loss, 0.000010 rate, 0.738198 seconds, 395072 images, 14017.062533 hours left
# Loaded: 0.000036 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.857496, GIOU: 0.855257), Class: 0.999911, Obj: 0.808027, No Obj: 0.001275, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.009219, iou_loss = 0.020762, total_loss = 0.029982
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.382099, GIOU: 0.285580), Class: 0.913876, Obj: 0.392110, No Obj: 0.006719, .5R: 0.347826, .75R: 0.086957, count: 46, class_loss = 7.201476, iou_loss = 5.248084, total_loss = 12.449559
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.818477, GIOU: 0.810675), Class: 0.967832, Obj: 0.546645, No Obj: 0.002052, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.205309, iou_loss = 0.059975, total_loss = 0.265284
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.809558, GIOU: 0.807455), Class: 0.445705, Obj: 0.785483, No Obj: 0.000615, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.778768, iou_loss = 0.093733, total_loss = 0.872501
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.851022, GIOU: 0.847835), Class: 0.996800, Obj: 0.507674, No Obj: 0.001020, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.246254, iou_loss = 0.033602, total_loss = 0.279856
# ...
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.709600, GIOU: 0.695818), Class: 0.977089, Obj: 0.622087, No Obj: 0.001141, .5R: 1.000000, .75R: 0.500000, count: 8, class_loss = 0.586119, iou_loss = 0.431794, total_loss = 1.017913
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.799942, GIOU: 0.792799), Class: 0.999901, Obj: 0.893755, No Obj: 0.001715, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.134808, iou_loss = 0.074775, total_loss = 0.209582
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.767499, GIOU: 0.761282), Class: 0.971020, Obj: 0.519253, No Obj: 0.001214, .5R: 1.000000, .75R: 0.750000, count: 8, class_loss = 0.811589, iou_loss = 0.327870, total_loss = 1.139459
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.766364, GIOU: 0.762037), Class: 0.998882, Obj: 0.860946, No Obj: 0.000750, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.007299, iou_loss = 0.058914, total_loss = 0.066213
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.582253, GIOU: 0.556661), Class: 0.992261, Obj: 0.568725, No Obj: 0.002214, .5R: 0.647059, .75R: 0.176471, count: 17, class_loss = 1.628243, iou_loss = 1.342299, total_loss = 2.970542
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.824238, GIOU: 0.820129), Class: 0.999811, Obj: 0.885600, No Obj: 0.002248, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.184088, iou_loss = 0.042041, total_loss = 0.226128
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.628028, GIOU: 0.596231), Class: 0.976662, Obj: 0.585467, No Obj: 0.000830, .5R: 0.750000, .75R: 0.250000, count: 8, class_loss = 0.600914, iou_loss = 0.407123, total_loss = 1.008037
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.691834, GIOU: 0.670705), Class: 0.995685, Obj: 0.308545, No Obj: 0.000359, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.244223, iou_loss = 0.102428, total_loss = 0.346651
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.505299, GIOU: 0.463418), Class: 0.963762, Obj: 0.503247, No Obj: 0.002667, .5R: 0.631579, .75R: 0.105263, count: 19, class_loss = 2.406597, iou_loss = 1.743908, total_loss = 4.150505
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.863783, GIOU: 0.861483), Class: 0.999774, Obj: 0.865022, No Obj: 0.002965, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.026548, iou_loss = 0.053639, total_loss = 0.080186
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.738878, GIOU: 0.735349), Class: 0.992361, Obj: 0.396890, No Obj: 0.000239, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.227700, iou_loss = 0.152626, total_loss = 0.380326
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.842505, GIOU: 0.841889), Class: 0.999802, Obj: 0.563030, No Obj: 0.000398, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.048509, iou_loss = 0.021779, total_loss = 0.070288
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.658129, GIOU: 0.635840), Class: 0.971364, Obj: 0.533357, No Obj: 0.001382, .5R: 0.727273, .75R: 0.272727, count: 11, class_loss = 1.012210, iou_loss = 0.684328, total_loss = 1.696538
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.642980, GIOU: 0.642980), Class: 0.995368, Obj: 0.388174, No Obj: 0.001014, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.275651, iou_loss = 0.134807, total_loss = 0.410459
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.797843, GIOU: 0.790263), Class: 0.997952, Obj: 0.944223, No Obj: 0.000483, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.006806, iou_loss = 0.075921, total_loss = 0.082727
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.736651, GIOU: 0.724839), Class: 0.999725, Obj: 0.771678, No Obj: 0.002752, .5R: 1.000000, .75R: 0.600000, count: 5, class_loss = 0.244776, iou_loss = 0.408392, total_loss = 0.653168
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.389355, GIOU: 0.169552), Class: 0.912620, Obj: 0.457733, No Obj: 0.000247, .5R: 0.500000, .75R: 0.500000, count: 2, class_loss = 0.357647, iou_loss = 0.620281, total_loss = 0.977929
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.762681, GIOU: 0.750486), Class: 0.970433, Obj: 0.683580, No Obj: 0.001887, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.226241, iou_loss = 0.119583, total_loss = 0.345824
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.566331, GIOU: 0.529500), Class: 0.823234, Obj: 0.421569, No Obj: 0.001660, .5R: 0.600000, .75R: 0.266667, count: 15, class_loss = 3.077991, iou_loss = 1.206432, total_loss = 4.284423
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.861269, GIOU: 0.860610), Class: 0.999997, Obj: 0.773909, No Obj: 0.000884, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.012937, iou_loss = 0.019668, total_loss = 0.032605
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.572306, GIOU: 0.538738), Class: 0.955560, Obj: 0.592820, No Obj: 0.003191, .5R: 0.541667, .75R: 0.250000, count: 24, class_loss = 2.405026, iou_loss = 1.790759, total_loss = 4.195785
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.812504, GIOU: 0.803780), Class: 0.999875, Obj: 0.787787, No Obj: 0.000762, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.014342, iou_loss = 0.035676, total_loss = 0.050018
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.713981, GIOU: 0.695861), Class: 0.963806, Obj: 0.680113, No Obj: 0.001739, .5R: 1.000000, .75R: 0.500000, count: 12, class_loss = 0.966014, iou_loss = 0.809147, total_loss = 1.775161
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.832915, GIOU: 0.830874), Class: 0.999999, Obj: 0.962496, No Obj: 0.001709, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.001214, iou_loss = 0.037364, total_loss = 0.038579
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.595148, GIOU: 0.569601), Class: 0.906063, Obj: 0.567480, No Obj: 0.001045, .5R: 0.833333, .75R: 0.166667, count: 6, class_loss = 0.844878, iou_loss = 0.324182, total_loss = 1.169061
#
#  6307: 1.119146, 1.011209 avg loss, 0.000010 rate, 1.010320 seconds, 403648 images, 15550.853801 hours left
# Loaded: 0.000039 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.690380, GIOU: 0.683816), Class: 0.984194, Obj: 0.546096, No Obj: 0.002716, .5R: 1.000000, .75R: 0.166667, count: 6, class_loss = 0.625044, iou_loss = 0.359014, total_loss = 0.984058
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.754711, GIOU: 0.744449), Class: 0.996060, Obj: 0.475247, No Obj: 0.000646, .5R: 1.000000, .75R: 0.333333, count: 3, class_loss = 0.542036, iou_loss = 0.114663, total_loss = 0.656699
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.794100, GIOU: 0.789207), Class: 0.999728, Obj: 0.921017, No Obj: 0.001485, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.106645, iou_loss = 0.059691, total_loss = 0.166336
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.542559, GIOU: 0.509142), Class: 0.980106, Obj: 0.511043, No Obj: 0.001810, .5R: 0.571429, .75R: 0.142857, count: 14, class_loss = 1.445895, iou_loss = 1.067201, total_loss = 2.513096
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.850686, GIOU: 0.849108), Class: 0.999643, Obj: 0.694029, No Obj: 0.001343, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.102171, iou_loss = 0.021133, total_loss = 0.123304
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.567661, GIOU: 0.520149), Class: 0.989179, Obj: 0.530485, No Obj: 0.000484, .5R: 0.750000, .75R: 0.000000, count: 4, class_loss = 0.353774, iou_loss = 0.279332, total_loss = 0.633106
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.751621, GIOU: 0.748118), Class: 0.995965, Obj: 0.892334, No Obj: 0.001434, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.009608, iou_loss = 0.090487, total_loss = 0.100095
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.570993, GIOU: 0.550690), Class: 0.932318, Obj: 0.434823, No Obj: 0.001255, .5R: 0.600000, .75R: 0.066667, count: 15, class_loss = 2.103296, iou_loss = 1.171256, total_loss = 3.274552
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.759196, GIOU: 0.759023), Class: 0.999889, Obj: 0.881667, No Obj: 0.001042, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.003513, iou_loss = 0.034539, total_loss = 0.038052
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.646979, GIOU: 0.621081), Class: 0.951852, Obj: 0.808654, No Obj: 0.000815, .5R: 0.800000, .75R: 0.000000, count: 5, class_loss = 0.220892, iou_loss = 0.293564, total_loss = 0.514456
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.860189, GIOU: 0.855564), Class: 0.999994, Obj: 0.964558, No Obj: 0.001518, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.001465, iou_loss = 0.056526, total_loss = 0.057991
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.660876, GIOU: 0.627424), Class: 0.998465, Obj: 0.466424, No Obj: 0.001329, .5R: 0.888889, .75R: 0.222222, count: 9, class_loss = 1.158197, iou_loss = 0.795845, total_loss = 1.954042
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000793, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.073586, iou_loss = 0.000000, total_loss = 0.073586
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.735566, GIOU: 0.731099), Class: 0.977223, Obj: 0.681016, No Obj: 0.001562, .5R: 1.000000, .75R: 0.545455, count: 11, class_loss = 0.648982, iou_loss = 0.508006, total_loss = 1.156989
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.901156, GIOU: 0.901081), Class: 0.999880, Obj: 0.858370, No Obj: 0.002636, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.057374, iou_loss = 0.035884, total_loss = 0.093258
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.670735, GIOU: 0.666432), Class: 0.984103, Obj: 0.532637, No Obj: 0.000264, .5R: 1.000000, .75R: 0.000000, count: 2, class_loss = 0.186255, iou_loss = 0.088938, total_loss = 0.275193
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.787466, GIOU: 0.777766), Class: 0.999043, Obj: 0.419630, No Obj: 0.002417, .5R: 1.000000, .75R: 0.500000, count: 4, class_loss = 0.405411, iou_loss = 0.146172, total_loss = 0.551583
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.651136, GIOU: 0.645306), Class: 0.999134, Obj: 0.965038, No Obj: 0.000511, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.215243, iou_loss = 0.074451, total_loss = 0.289693
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.801943, GIOU: 0.797050), Class: 0.999836, Obj: 0.899555, No Obj: 0.002200, .5R: 1.000000, .75R: 0.500000, count: 2, class_loss = 0.132263, iou_loss = 0.053694, total_loss = 0.185957
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.747107, GIOU: 0.731400), Class: 0.954481, Obj: 0.734753, No Obj: 0.001424, .5R: 0.909091, .75R: 0.727273, count: 11, class_loss = 0.624064, iou_loss = 1.045060, total_loss = 1.669125
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.848210, GIOU: 0.846190), Class: 1.000000, Obj: 0.997644, No Obj: 0.000748, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000489, iou_loss = 0.026891, total_loss = 0.027379
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.567404, GIOU: 0.529664), Class: 0.966213, Obj: 0.534969, No Obj: 0.002783, .5R: 0.652174, .75R: 0.260870, count: 23, class_loss = 2.398431, iou_loss = 1.478065, total_loss = 3.876496
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.787573, GIOU: 0.775535), Class: 0.999850, Obj: 0.849870, No Obj: 0.002471, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.090272, iou_loss = 0.154828, total_loss = 0.245100
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.604334, GIOU: 0.570471), Class: 0.976952, Obj: 0.445775, No Obj: 0.003421, .5R: 0.758621, .75R: 0.241379, count: 29, class_loss = 4.071132, iou_loss = 2.120397, total_loss = 6.191529
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.794770, GIOU: 0.777069), Class: 0.999279, Obj: 0.822629, No Obj: 0.002180, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.070106, iou_loss = 0.223440, total_loss = 0.293545
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.724763, GIOU: 0.711582), Class: 0.930541, Obj: 0.741306, No Obj: 0.001909, .5R: 0.909091, .75R: 0.454545, count: 11, class_loss = 0.677781, iou_loss = 0.846855, total_loss = 1.524636
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.896234, GIOU: 0.896234), Class: 0.999995, Obj: 0.780956, No Obj: 0.001155, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.012051, iou_loss = 0.011477, total_loss = 0.023528
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.743061, GIOU: 0.731112), Class: 0.993385, Obj: 0.667056, No Obj: 0.002187, .5R: 0.923077, .75R: 0.461538, count: 13, class_loss = 1.118524, iou_loss = 0.641312, total_loss = 1.759836
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.761435, GIOU: 0.759382), Class: 0.997853, Obj: 0.529478, No Obj: 0.001376, .5R: 1.000000, .75R: 0.666667, count: 3, class_loss = 0.304096, iou_loss = 0.100650, total_loss = 0.404746
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.717143, GIOU: 0.679806), Class: 0.967018, Obj: 0.624058, No Obj: 0.001495, .5R: 0.900000, .75R: 0.600000, count: 10, class_loss = 1.100312, iou_loss = 0.873415, total_loss = 1.973728
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.825632, GIOU: 0.823077), Class: 0.995804, Obj: 0.521549, No Obj: 0.001081, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.228750, iou_loss = 0.052556, total_loss = 0.281305
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.734927, GIOU: 0.724932), Class: 0.990362, Obj: 0.542185, No Obj: 0.001662, .5R: 1.000000, .75R: 0.545455, count: 11, class_loss = 1.440389, iou_loss = 0.439734, total_loss = 1.880123
#
#  6308: 1.056035, 1.015691 avg loss, 0.000010 rate, 0.988361 seconds, 403712 images, 15535.714386 hours left
# Loaded: 0.000066 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.891245, GIOU: 0.888552), Class: 0.999749, Obj: 0.981946, No Obj: 0.002173, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.039884, iou_loss = 0.026380, total_loss = 0.066264
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.782572, GIOU: 0.779591), Class: 0.989038, Obj: 0.639167, No Obj: 0.000548, .5R: 1.000000, .75R: 0.750000, count: 4, class_loss = 0.244700, iou_loss = 0.097769, total_loss = 0.342469
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.845008, GIOU: 0.840600), Class: 0.999997, Obj: 0.991069, No Obj: 0.000726, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.000390, iou_loss = 0.027388, total_loss = 0.027779
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.556572, GIOU: 0.502958), Class: 0.976999, Obj: 0.535523, No Obj: 0.003887, .5R: 0.758621, .75R: 0.241379, count: 29, class_loss = 3.368330, iou_loss = 2.157599, total_loss = 5.525929
# ^C

# %% [markdown]
# ### Utility Functions

# %%
# Define threshold for confidence score and Non max supression here
confthres=0.2
nmsthres=0.1
path="./"
def get_labels(label_dir):
    return open(label_dir).read().split('\n')
      
def get_colors(LABELS):
    # initialize a list of colors to represent each possible class label
    np.random.seed(42)
    COLORS = np.random.randint(0, 255, size=(len(LABELS), 3),dtype="uint8")
    return COLORS

def get_weights(weights_path):
    # derive the paths to the YOLO weights and model configuration
    weightsPath = os.path.sep.join([yolo_path, weights_path])
    return weightsPath

def get_config(config_path):
    configPath = os.path.sep.join([yolo_path, config_path])
    return configPath

def load_model(configpath,weightspath):
    # load our YOLO object detector trained on COCO dataset (80 classes)
    print("[INFO] loading YOLO from disk...")
    net = cv2.dnn.readNetFromDarknet(configpath, weightspath)
    return net

# %%
#https://medium.com/analytics-vidhya/object-detection-using-yolo-v3-and-deploying-it-on-docker-and-minikube-c1192e81ae7a
def get_predection(image,net,LABELS,COLORS):
    (H, W) = image.shape[:2]

    # determine only the *output* layer names that we need from YOLO
    ln = net.getLayerNames()
    ln = [ln[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    # construct a blob from the input image and then perform a forward
    # pass of the YOLO object detector, giving us our bounding boxes and
    # associated probabilities
    blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416),
                                 swapRB=True, crop=False)
    net.setInput(blob)
    start = time.time()
    layerOutputs = net.forward(ln)
    #print(layerOutputs[0])
    end = time.time()

    # show timing information on YOLO
    #print("[INFO] YOLO took {:.6f} seconds".format(end - start))

    # initialize our lists of detected bounding boxes, confidences, and
    # class IDs, respectively
    boxes = []
    confidences = []
    classIDs = []
    num_class_0 = 0
    num_class_1 = 0

    # loop over each of the layer outputs
    for output in layerOutputs:
        # loop over each of the detections
        for detection in output:
            # extract the class ID and confidence (i.e., probability) of
            # the current object detection
            scores = detection[5:]
            #print(detection)
            classID = np.argmax(scores)
            # print(classID)
            confidence = scores[classID]

            # filter out weak predictions by ensuring the detected
            # probability is greater than the minimum probability
            if confidence > confthres:
                # scale the bounding box coordinates back relative to the
                # size of the image, keeping in mind that YOLO actually
                # returns the center (x, y)-coordinates of the bounding
                # box followed by the boxes' width and height
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY, width, height) = box.astype("int")

                # use the center (x, y)-coordinates to derive the top and
                # and left corner of the bounding box
                x = int(centerX - (width / 2))
                y = int(centerY - (height / 2))

                # update our list of bounding box coordinates, confidences,
                # and class IDs
                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                classIDs.append(classID)
                if(classID==0):
                  num_class_0 +=1
                elif(classID==1):
                  num_class_1 +=1  

    # apply non-maxima suppression to suppress weak, overlapping bounding
    # boxes
    idxs = cv2.dnn.NMSBoxes(boxes, confidences, confthres,
                            nmsthres)
    if(num_class_0>0 or num_class_1>0):
        index= num_class_0/(num_class_0+num_class_1)
    else:
      index=-1  
    #print(index,)    
    # ensure at least one detection exists
    if len(idxs) > 0:
        # loop over the indexes we are keeping
        for i in idxs.flatten():
            # extract the bounding box coordinates
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            # draw a bounding box rectangle and label on the image
            color = [int(c) for c in COLORS[classIDs[i]]]
            cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
            text = "{}".format(LABELS[classIDs[i]])
            #print(boxes)
            #print(classIDs)      
            #cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,0.5, color=(69, 60, 90), thickness=2)
            cv2.rectangle(image, (x, y-5), (x+62, y-15), color, cv2.FILLED)
            cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,0,0), 1)
            if(index!=-1 and index<.50):
                cv2.rectangle(image, (40, 46), (220, 16), (0,0,255), cv2.FILLED)
                cv2.putText(image,'Mask Adaptivity: POOR',(40,40),cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,255,255), 1)
            elif(index>=.50 and index<.70):
                cv2.rectangle(image, (40, 46), (255, 16), (0, 165, 255), cv2.FILLED)
                cv2.putText(image,'Mask Adaptivity: MODERATE',(40,40),cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,0,0), 1)  
            elif(index>=0.70):
                cv2.rectangle(image, (40, 46), (220, 16), (42,236,42), cv2.FILLED)
                cv2.putText(image,'Mask Adaptivity: HIGH',(40,40),cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,0,0), 1)      
    return image

# %%
def predict_image(img_path):
    image = cv2.imread(img_path)
    nets=load_model(CFG,Weights)
    #Colors=get_colors(Lables)
    Colors=[(42,236,42),(0,0,255)]
    res=get_predection(image,nets,Lables,Colors)
    # image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    # show the output image
    cv2_imshow(res)
    cv2.waitKey()

# %%
def predict_video(input_path,output_path):
    vid = cv2.VideoCapture(input_path)
    op=output_path
    height, width = None, None
    writer = None
    print('[Info] processing Video (It may take several minutes to Run)..')
    while True:
        grabbed, frame = vid.read()
		    # Checking if the complete video is read
        if not grabbed:
		        break
        if width is None or height is None:
		        height, width = frame.shape[:2]
        frame=get_predection(frame,nets,Lables,Colors)
        if writer is None:
          fourcc = cv2.VideoWriter_fourcc(*"mp4v")
          writer = cv2.VideoWriter(op, fourcc, 27,(frame.shape[1], frame.shape[0]), True)
        writer.write(frame)
    print ("[INFO] Cleaning up...")
    writer.release()
    vid.release()
    print ("[INFO] Prediction Completed.")

# %%
# This will not work  in colab, as colab can't access local hardware
import time
def predict_web_cam():
    #stream = cv2.VideoCapture(0)
    sess = K.get_session()
    while True:
        # Capture frame-by-frame
        grabbed, frame = stream.read()
        if not grabbed:
            break
        # Run detection
        start = time.time()
        image = Image.fromarray(frame)
        output_image =  get_predection(image,nets,Lables,Colors)
        end = time.time()
        print("Inference time: {:.2f}s".format(end - start))
        # Display the resulting frame
        cv2.imshow('Web Cam',np.asarray(output_image))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    stream.release()    
    cv2.destroyAllWindows()

# %% [markdown]
# ### Set the Variables (Must before Prediction)

# %%
# Set the pah for test config file, label directory and weights
CFG='/content/darknet/YOLO_Custom/yolov3-tiny_obj_test.cfg'   
label_dir='/content/darknet/YOLO_Custom/obj.names'
cfgpath=test_config_path
Weights='/content/darknet/YOLO_Custom/yolov3-tiny_obj_train_tiny8.weights'
Lables=get_labels(label_dir)

# %% [markdown]
# ### Predict Image

# %%
    from google.colab.patches import cv2_imshow
    img_path='/content/darknet/YOLO_Custom/images/image_502.jpg' 
    predict_image(img_path)
# Out:
# [INFO] loading YOLO from disk...
# <PIL.Image.Image image mode=RGB size=612x408 at 0x7FC0B07285F8>

# %% [markdown]
# ### Predict Video

# %%
input_path='/content/in.mp4'
output_path='/content/out.mp4'
predict_video(input_path,output_path)
# Out:
# processing..
# [INFO] Cleaning up...
